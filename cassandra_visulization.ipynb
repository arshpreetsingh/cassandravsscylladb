# %% [markdown]
# <a href="https://colab.research.google.com/github/arshpreetsingh/cassandravsscylladb/blob/master/cassandra_visulization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_frame=pd.read_csv("/test1_cassandra_363.csv")

# %%
df = pd.read_csv("/test1_cassandra_363.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=df)

# %%
data_frame_test2 = pd.read_csv("/test2_cassandra_393.csv")

# %%
data_frame_test2 = pd.read_csv("/test2_cassandra_393.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=data_frame_test2)

# %%
data_frame_test3 = pd.read_csv("/test3_10000_1503.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=data_frame_test3)

# %%
data_frame_test4 = pd.read_csv("/test4_10000_4M_1306.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=data_frame_test4)

# %%
data_frame_test5 = pd.read_csv("/test5_50000_8M+---.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=data_frame_test5)

# %%
data_frame_read_test1 = pd.read_csv("/test1_read_2700_100clients_2B.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=data_frame_read_test1)

# %%
data_frame_read_test2 = pd.read_csv("/test2_read_5835_1000clients_65M.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=data_frame_read_test2)

# %%
data_frame_read_write_reat1 = pd.read_csv("/test_R3000_w_10000_463_Write.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=data_frame_read_write_reat1)

# %%
data_frame_read_write_reat2 = pd.read_csv("/test1_read3000_w10000_811_5M_READ.csv", names=['Number Of Operations', 'Time/1000 Operations'])

# %%
sns.lineplot(x='Number Of Operations', y='Time/1000 Operations', data=data_frame_read_write_reat2)
